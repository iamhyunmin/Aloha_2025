# %%
# -*- coding: utf-8 -*-
"""
유니크 매장(ENCODED_MCT 기준) → Google Places API로 '별점(rating)' + '리뷰수(user_ratings_total)'만 수집
- Text Search → place_id 매칭
- Place Details (fields=rating,user_ratings_total) 조회
- 무료 구간 보호를 위한 '하드 스톱' 포함
- 진행률/ETA 출력 + 주기적 체크포인트 저장 + 응답 캐시 + 제한적 백오프 재시도

필수:
  export GOOGLE_MAPS_API_KEY="AIzaSyCYJ6yHOY4ATy1RVGKFI7IwwKZblf2aMbQ"

설치:
  pip install requests pandas
"""

import os, re, time, json, math, requests, pandas as pd
from datetime import timedelta

# ================== 경로/설정 ==================
SRC = "store_month_df_buckedted2.csv"           # 입력 (수정 가능)
DST = "store_unique_with_google_rating.csv"     # 최종 출력
CACHE_DIR = "/mnt/data/.gplaces_cache"; os.makedirs(CACHE_DIR, exist_ok=True)
CHKPT_EVERY = 200   # N건마다 체크포인트 저장

ID_COL   = "ENCODED_MCT"
NAME_COL = "MCT_NM"
ADDR_COL = "MCT_BSE_AR"

# 호출 간 sleep 및 재시도 백오프
SLEEP = 0.18
MAX_RETRY = 2               # 429/5xx에 한해 2회 재시도
BACKOFF_BASE = 0.6          # 지수 백오프 시작

# ================== 무료 한도 하드 스톱 ==================
# Google Places (New) 무료 사용량 캡을 여유 있게 보전
TS_FREE_LIMIT = 5000     # Text Search 월 무료
DT_FREE_LIMIT = 10000    # Place Details (Essentials) 월 무료
TS_HARD_STOP  = 4800     # 안전 여유치로 조기 중단
DT_HARD_STOP  = 9000     # 안전 여유치로 조기 중단

TS_CALLS = 0             # 실행 중 누적 카운터(캐시 히트는 미포함)
DT_CALLS = 0

# ================== Google Places API ==================
API_KEY = "AIzaSyCYJ6yHOY4ATy1RVGKFI7IwwKZblf2aMbQ"
assert API_KEY, "환경변수 GOOGLE_MAPS_API_KEY 가 비었습니다. 먼저 설정하세요."

SESSION = requests.Session()

# ================== 유틸 ==================
def read_csv_safely(path: str) -> pd.DataFrame:
    try:
        return pd.read_csv(path)
    except UnicodeDecodeError:
        return pd.read_csv(path, encoding="cp949")

def norm_prefix2(name: str) -> str:
    """마스킹 상호에서도 앞 2글자 접두어 추출"""
    name = (name or "").strip()
    m = re.match(r"^[\w가-힣]+", name)
    base = m.group(0) if m else ""
    base = re.sub(r"\s+", "", base)
    base = re.sub(r"[^\w가-힣]", "", base)
    return base[:2]

def cache_path(key: str) -> str:
    key = re.sub(r"[^A-Za-z0-9가-힣]+", "_", key)[:140]
    return os.path.join(CACHE_DIR, key + ".json")

def fmt_hms(seconds: float) -> str:
    if seconds < 0: seconds = 0
    return str(timedelta(seconds=int(seconds)))

def eta_report(start_ts: float, done: int, total: int) -> str:
    elapsed = time.time() - start_ts
    per = elapsed / max(done, 1)
    remain = (total - done) * per
    return f"{done}/{total} avg:{per:.2f}s/store elapsed:{fmt_hms(elapsed)} ETA:{fmt_hms(remain)}"

def pick_representative(df: pd.DataFrame) -> pd.DataFrame:
    """같은 ID 내 대표 주소: 최빈값(mode) → 없으면 첫 유효값. 이름은 첫 유효값."""
    def mode_or_first(s: pd.Series):
        s = s.dropna()
        if s.empty: return None
        m = s.mode()
        return m.iloc[0] if not m.empty else s.iloc[0]
    reps = (df[[ID_COL, NAME_COL, ADDR_COL]]
            .dropna(subset=[ADDR_COL])
            .groupby(ID_COL, as_index=False)
            .agg({NAME_COL: lambda x: x.dropna().iloc[0] if x.dropna().size else None,
                  ADDR_COL: mode_or_first}))
    return reps

# ================== HTTP 호출 래퍼(재시도/백오프) ==================
def _get_with_retry(url: str, params: dict):
    """429/5xx에 한해 MAX_RETRY까지 백오프 재시도"""
    for attempt in range(MAX_RETRY + 1):
        r = SESSION.get(url, params=params, timeout=15)
        if r.status_code < 500 and r.status_code != 429:
            r.raise_for_status()
            return r
        # 재시도 조건(429/5xx)
        if attempt < MAX_RETRY:
            sleep_s = BACKOFF_BASE * (2 ** attempt)
            time.sleep(sleep_s)
            continue
        r.raise_for_status()
    # 논리상 도달하지 않음
    return r

# ================== Places API 함수(하드스톱 포함) ==================
def gplaces_text_search(query: str, region="kr", language="ko"):
    global TS_CALLS
    if TS_CALLS >= TS_HARD_STOP:
        raise RuntimeError(f"[HARD-STOP] TextSearch {TS_CALLS}/{TS_HARD_STOP} 도달. 자동 중단.")
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json"
    r = _get_with_retry(url, {
        "query": query, "key": API_KEY, "region": region, "language": language
    })
    TS_CALLS += 1
    time.sleep(SLEEP)
    return r.json()

def gplaces_details(place_id: str, fields="rating,user_ratings_total", language="ko"):
    global DT_CALLS
    if DT_CALLS >= DT_HARD_STOP:
        raise RuntimeError(f"[HARD-STOP] PlaceDetails {DT_CALLS}/{DT_HARD_STOP} 도달. 자동 중단.")
    url = "https://maps.googleapis.com/maps/api/place/details/json"
    r = _get_with_retry(url, {
        "place_id": place_id, "fields": fields, "key": API_KEY, "language": language
    })
    DT_CALLS += 1
    time.sleep(SLEEP)
    return r.json()

# ================== 매칭/조회 로직 ==================
def match_place_id(name_masked: str, address: str):
    """
    이름 접두어 2글자 + 주소 토큰을 섞어 Text Search → 가장 그럴듯한 후보 선택
    - 캐시: 쿼리 문자열 기준
    - 간단 스코어: 접두어 일치 가산 + 리뷰수 가중
    """
    p2 = norm_prefix2(name_masked)
    addr_tokens = re.findall(r"[가-힣A-Za-z0-9]+", address)[:2]  # 노이즈 감소
    query = f"{p2} {' '.join(addr_tokens)} {address}".strip() if p2 else address

    cp = cache_path("ts_" + query)
    if os.path.exists(cp):
        data = json.load(open(cp, "r", encoding="utf-8"))
    else:
        data = gplaces_text_search(query)
        json.dump(data, open(cp, "w", encoding="utf-8"), ensure_ascii=False)

    results = data.get("results", [])
    if not results:
        return None, "not_found"

    def score(item):
        nm = (item.get("name") or "").replace(" ", "")
        s = 0.0
        if p2 and nm.startswith(p2): s += 5.0
        s += min((item.get("user_ratings_total", 0) or 0) / 100.0, 5.0)
        return s

    best = max(results, key=score)
    return best.get("place_id"), "ok"

def get_rating(place_id: str):
    """Place Details에서 rating/user_ratings_total만 조회(캐시 사용, 하드스톱 연동)"""
    if not place_id:
        return None, None, "no_place_id"
    cp = cache_path("dt_" + place_id)
    if os.path.exists(cp):
        data = json.load(open(cp, "r", encoding="utf-8"))
        status = data.get("status", "OK")
    else:
        data = gplaces_details(place_id, fields="rating,user_ratings_total")
        status = data.get("status", "OK")
        json.dump(data, open(cp, "w", encoding="utf-8"), ensure_ascii=False)
    res = data.get("result", {}) or {}
    return res.get("rating"), res.get("user_ratings_total"), status

# ================== 메인 ==================
def main():
    global TS_CALLS, DT_CALLS
    df = read_csv_safely(SRC)
    for c in [ID_COL, NAME_COL, ADDR_COL]:
        assert c in df.columns, f"필수 컬럼 누락: {c}"

    reps = pick_representative(df)
    total = len(reps)
    print(f"[INFO] unique stores: {total}")
    print(f"[LIMIT] TextSearch hard-stop:{TS_HARD_STOP} (free:{TS_FREE_LIMIT}), "
          f"Details hard-stop:{DT_HARD_STOP} (free:{DT_FREE_LIMIT})")

    rows = []
    start = time.time()
    last_ckpt = time.time()

    for i, r in enumerate(reps.itertuples(index=False), 1):
        sid = str(getattr(r, ID_COL))
        nm  = str(getattr(r, NAME_COL)) if pd.notna(getattr(r, NAME_COL)) else ""
        ad  = str(getattr(r, ADDR_COL)) if pd.notna(getattr(r, ADDR_COL)) else ""

        try:
            pid, st1 = match_place_id(nm, ad)
            rating, cnt, st2 = get_rating(pid) if pid else (None, None, st1)
            rows.append({
                "ENCODED_MCT": sid,
                "MCT_BSE_AR": ad,
                "g_place_id": pid,
                "g_rating": rating,
                "g_user_ratings_total": cnt,
                "status": st2 if pid else st1
            })
        except requests.HTTPError as e:
            rows.append({"ENCODED_MCT": sid, "MCT_BSE_AR": ad,
                         "g_place_id": None, "g_rating": None, "g_user_ratings_total": None,
                         "status": f"http_{getattr(e.response,'status_code','err')}"})
        except RuntimeError as e:
            # 하드스톱 도달 시 현재까지 저장 후 종료
            print(f"[STOP] {e}")
            pd.DataFrame(rows).to_csv(DST, index=False)
            print(f"[SAVED] partial -> {DST} (rows: {len(rows)})")
            print(f"[COUNT] TS:{TS_CALLS} / DT:{DT_CALLS}")
            return
        except Exception as e:
            rows.append({"ENCODED_MCT": sid, "MCT_BSE_AR": ad,
                         "g_place_id": None, "g_rating": None, "g_user_ratings_total": None,
                         "status": f"error:{type(e).__name__}"})

        # 진행률/ETA/카운터 로그
        if i == 1 or i % 20 == 0:
            print("[PROGRESS]", eta_report(start, i, total), f" | [COUNT] TS:{TS_CALLS} DT:{DT_CALLS}")

        # 주기적 체크포인트 저장(건수 또는 3분 간격)
        if i % CHKPT_EVERY == 0 or (time.time() - last_ckpt > 180):
            pd.DataFrame(rows).to_csv(DST, index=False)
            last_ckpt = time.time()
            print(f"[CKPT] saved {i} rows -> {DST}")

    out = pd.DataFrame(rows)
    out.to_csv(DST, index=False)
    print(f"[DONE] saved -> {DST} (rows: {len(out)})")
    print(f"[COUNT] TS:{TS_CALLS} / DT:{DT_CALLS}")
    print("[SUMMARY]", eta_report(start, total, total))

if __name__ == "__main__":
    main()
# Out:
# [INFO] unique stores: 4185
# [LIMIT] TextSearch hard-stop:4800 (free:5000), Details hard-stop:9000 (free:10000)
# [PROGRESS] 1/4185 avg:1.31s/store elapsed:0:00:01 ETA:1:31:38  | [COUNT] TS:1 DT:1
# [PROGRESS] 20/4185 avg:1.00s/store elapsed:0:00:19 ETA:1:09:09  | [COUNT] TS:20 DT:20
# [PROGRESS] 40/4185 avg:0.95s/store elapsed:0:00:38 ETA:1:05:39  | [COUNT] TS:40 DT:39
# [PROGRESS] 60/4185 avg:0.92s/store elapsed:0:00:55 ETA:1:03:15  | [COUNT] TS:59 DT:57
# [PROGRESS] 80/4185 avg:0.93s/store elapsed:0:01:14 ETA:1:03:48  | [COUNT] TS:79 DT:77
# [PROGRESS] 100/4185 avg:0.91s/store elapsed:0:01:31 ETA:1:02:05  | [COUNT] TS:99 DT:92
# [PROGRESS] 120/4185 avg:0.90s/store elapsed:0:01:48 ETA:1:01:18  | [COUNT] TS:119 DT:110
# [PROGRESS] 140/4185 avg:0.91s/store elapsed:0:02:06 ETA:1:01:04  | [COUNT] TS:139 DT:129
# [PROGRESS] 160/4185 avg:0.90s/store elapsed:0:02:24 ETA:1:00:42  | [COUNT] TS:159 DT:147
# [PROGRESS] 180/4185 avg:0.90s/store elapsed:0:02:42 ETA:1:00:11  | [COUNT] TS:179 DT:165
# [PROGRESS] 200/4185 avg:0.90s/store elapsed:0:02:59 ETA:0:59:45  | [COUNT] TS:199 DT:183
# [CKPT] saved 200 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 220/4185 avg:0.90s/store elapsed:0:03:18 ETA:0:59:35  | [COUNT] TS:219 DT:201
# [PROGRESS] 240/4185 avg:0.90s/store elapsed:0:03:36 ETA:0:59:11  | [COUNT] TS:239 DT:218
# [PROGRESS] 260/4185 avg:0.90s/store elapsed:0:03:53 ETA:0:58:39  | [COUNT] TS:259 DT:233
# [PROGRESS] 280/4185 avg:0.89s/store elapsed:0:04:10 ETA:0:58:13  | [COUNT] TS:279 DT:250
# [PROGRESS] 300/4185 avg:0.90s/store elapsed:0:04:28 ETA:0:58:02  | [COUNT] TS:299 DT:268
# [PROGRESS] 320/4185 avg:0.90s/store elapsed:0:04:47 ETA:0:57:54  | [COUNT] TS:319 DT:288
# [PROGRESS] 340/4185 avg:0.90s/store elapsed:0:05:05 ETA:0:57:36  | [COUNT] TS:339 DT:306
# [PROGRESS] 360/4185 avg:0.90s/store elapsed:0:05:23 ETA:0:57:17  | [COUNT] TS:359 DT:323
# [PROGRESS] 380/4185 avg:0.90s/store elapsed:0:05:41 ETA:0:56:59  | [COUNT] TS:379 DT:341
# [PROGRESS] 400/4185 avg:0.90s/store elapsed:0:05:59 ETA:0:56:40  | [COUNT] TS:399 DT:357
# [CKPT] saved 400 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 420/4185 avg:0.90s/store elapsed:0:06:15 ETA:0:56:10  | [COUNT] TS:418 DT:371
# [PROGRESS] 440/4185 avg:0.90s/store elapsed:0:06:34 ETA:0:55:53  | [COUNT] TS:438 DT:387
# [PROGRESS] 460/4185 avg:0.89s/store elapsed:0:06:51 ETA:0:55:31  | [COUNT] TS:458 DT:405
# [PROGRESS] 480/4185 avg:0.89s/store elapsed:0:07:08 ETA:0:55:11  | [COUNT] TS:478 DT:421
# [PROGRESS] 500/4185 avg:0.89s/store elapsed:0:07:25 ETA:0:54:43  | [COUNT] TS:498 DT:434
# [PROGRESS] 520/4185 avg:0.89s/store elapsed:0:07:41 ETA:0:54:15  | [COUNT] TS:518 DT:449
# [PROGRESS] 540/4185 avg:0.89s/store elapsed:0:07:59 ETA:0:53:53  | [COUNT] TS:538 DT:465
# [PROGRESS] 560/4185 avg:0.89s/store elapsed:0:08:16 ETA:0:53:30  | [COUNT] TS:558 DT:480
# [PROGRESS] 580/4185 avg:0.89s/store elapsed:0:08:33 ETA:0:53:12  | [COUNT] TS:578 DT:496
# [PROGRESS] 600/4185 avg:0.88s/store elapsed:0:08:49 ETA:0:52:45  | [COUNT] TS:598 DT:510
# [CKPT] saved 600 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 620/4185 avg:0.88s/store elapsed:0:09:06 ETA:0:52:21  | [COUNT] TS:618 DT:523
# [PROGRESS] 640/4185 avg:0.88s/store elapsed:0:09:23 ETA:0:52:03  | [COUNT] TS:638 DT:538
# [PROGRESS] 660/4185 avg:0.88s/store elapsed:0:09:40 ETA:0:51:42  | [COUNT] TS:658 DT:553
# [PROGRESS] 680/4185 avg:0.88s/store elapsed:0:09:59 ETA:0:51:27  | [COUNT] TS:678 DT:568
# [PROGRESS] 700/4185 avg:0.88s/store elapsed:0:10:16 ETA:0:51:09  | [COUNT] TS:698 DT:585
# [PROGRESS] 720/4185 avg:0.88s/store elapsed:0:10:33 ETA:0:50:48  | [COUNT] TS:718 DT:602
# [PROGRESS] 740/4185 avg:0.88s/store elapsed:0:10:50 ETA:0:50:29  | [COUNT] TS:738 DT:617
# [PROGRESS] 760/4185 avg:0.88s/store elapsed:0:11:08 ETA:0:50:12  | [COUNT] TS:758 DT:636
# [PROGRESS] 780/4185 avg:0.88s/store elapsed:0:11:26 ETA:0:49:56  | [COUNT] TS:778 DT:652
# [PROGRESS] 800/4185 avg:0.88s/store elapsed:0:11:42 ETA:0:49:31  | [COUNT] TS:798 DT:663
# [CKPT] saved 800 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 820/4185 avg:0.88s/store elapsed:0:12:00 ETA:0:49:18  | [COUNT] TS:817 DT:679
# [PROGRESS] 840/4185 avg:0.88s/store elapsed:0:12:17 ETA:0:48:56  | [COUNT] TS:836 DT:692
# [PROGRESS] 860/4185 avg:0.88s/store elapsed:0:12:34 ETA:0:48:37  | [COUNT] TS:856 DT:708
# [PROGRESS] 880/4185 avg:0.88s/store elapsed:0:12:52 ETA:0:48:19  | [COUNT] TS:876 DT:724
# [PROGRESS] 900/4185 avg:0.88s/store elapsed:0:13:09 ETA:0:48:01  | [COUNT] TS:896 DT:740
# [PROGRESS] 920/4185 avg:0.88s/store elapsed:0:13:27 ETA:0:47:45  | [COUNT] TS:916 DT:757
# [PROGRESS] 940/4185 avg:0.88s/store elapsed:0:13:44 ETA:0:47:24  | [COUNT] TS:935 DT:772
# [PROGRESS] 960/4185 avg:0.88s/store elapsed:0:14:01 ETA:0:47:08  | [COUNT] TS:955 DT:788
# [PROGRESS] 980/4185 avg:0.88s/store elapsed:0:14:18 ETA:0:46:46  | [COUNT] TS:974 DT:803
# [PROGRESS] 1000/4185 avg:0.87s/store elapsed:0:14:34 ETA:0:46:23  | [COUNT] TS:994 DT:816
# [CKPT] saved 1000 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 1020/4185 avg:0.87s/store elapsed:0:14:50 ETA:0:46:02  | [COUNT] TS:1014 DT:829
# [PROGRESS] 1040/4185 avg:0.87s/store elapsed:0:15:07 ETA:0:45:45  | [COUNT] TS:1034 DT:844
# [PROGRESS] 1060/4185 avg:0.87s/store elapsed:0:15:24 ETA:0:45:25  | [COUNT] TS:1054 DT:857
# [PROGRESS] 1080/4185 avg:0.87s/store elapsed:0:15:41 ETA:0:45:06  | [COUNT] TS:1074 DT:871
# [PROGRESS] 1100/4185 avg:0.87s/store elapsed:0:15:59 ETA:0:44:50  | [COUNT] TS:1094 DT:887
# [PROGRESS] 1120/4185 avg:0.87s/store elapsed:0:16:16 ETA:0:44:31  | [COUNT] TS:1114 DT:902
# [PROGRESS] 1140/4185 avg:0.87s/store elapsed:0:16:32 ETA:0:44:11  | [COUNT] TS:1133 DT:918
# [PROGRESS] 1160/4185 avg:0.87s/store elapsed:0:16:49 ETA:0:43:53  | [COUNT] TS:1153 DT:934
# [PROGRESS] 1180/4185 avg:0.87s/store elapsed:0:17:08 ETA:0:43:38  | [COUNT] TS:1173 DT:952
# [PROGRESS] 1200/4185 avg:0.87s/store elapsed:0:17:24 ETA:0:43:19  | [COUNT] TS:1193 DT:967
# [CKPT] saved 1200 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 1220/4185 avg:0.87s/store elapsed:0:17:41 ETA:0:42:58  | [COUNT] TS:1213 DT:979
# [PROGRESS] 1240/4185 avg:0.87s/store elapsed:0:17:57 ETA:0:42:39  | [COUNT] TS:1233 DT:992
# [PROGRESS] 1260/4185 avg:0.87s/store elapsed:0:18:15 ETA:0:42:23  | [COUNT] TS:1253 DT:1008
# [PROGRESS] 1280/4185 avg:0.87s/store elapsed:0:18:33 ETA:0:42:06  | [COUNT] TS:1273 DT:1021
# [PROGRESS] 1300/4185 avg:0.87s/store elapsed:0:18:50 ETA:0:41:48  | [COUNT] TS:1292 DT:1037
# [PROGRESS] 1320/4185 avg:0.87s/store elapsed:0:19:06 ETA:0:41:28  | [COUNT] TS:1312 DT:1050
# [PROGRESS] 1340/4185 avg:0.87s/store elapsed:0:19:23 ETA:0:41:10  | [COUNT] TS:1332 DT:1064
# [PROGRESS] 1360/4185 avg:0.87s/store elapsed:0:19:39 ETA:0:40:50  | [COUNT] TS:1352 DT:1077
# [PROGRESS] 1380/4185 avg:0.87s/store elapsed:0:19:55 ETA:0:40:29  | [COUNT] TS:1371 DT:1090
# [PROGRESS] 1400/4185 avg:0.87s/store elapsed:0:20:13 ETA:0:40:14  | [COUNT] TS:1391 DT:1108
# [CKPT] saved 1400 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 1420/4185 avg:0.87s/store elapsed:0:20:30 ETA:0:39:56  | [COUNT] TS:1411 DT:1120
# [PROGRESS] 1440/4185 avg:0.87s/store elapsed:0:20:47 ETA:0:39:38  | [COUNT] TS:1431 DT:1136
# [PROGRESS] 1460/4185 avg:0.87s/store elapsed:0:21:04 ETA:0:39:19  | [COUNT] TS:1451 DT:1148
# [PROGRESS] 1480/4185 avg:0.87s/store elapsed:0:21:21 ETA:0:39:01  | [COUNT] TS:1471 DT:1163
# [PROGRESS] 1500/4185 avg:0.86s/store elapsed:0:21:37 ETA:0:38:42  | [COUNT] TS:1491 DT:1175
# [PROGRESS] 1520/4185 avg:0.86s/store elapsed:0:21:53 ETA:0:38:23  | [COUNT] TS:1511 DT:1186
# [PROGRESS] 1540/4185 avg:0.86s/store elapsed:0:22:08 ETA:0:38:01  | [COUNT] TS:1529 DT:1196
# [PROGRESS] 1560/4185 avg:0.86s/store elapsed:0:22:24 ETA:0:37:42  | [COUNT] TS:1549 DT:1208
# [PROGRESS] 1580/4185 avg:0.86s/store elapsed:0:22:41 ETA:0:37:24  | [COUNT] TS:1569 DT:1222
# [PROGRESS] 1600/4185 avg:0.86s/store elapsed:0:22:58 ETA:0:37:07  | [COUNT] TS:1589 DT:1237
# [CKPT] saved 1600 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 1620/4185 avg:0.86s/store elapsed:0:23:16 ETA:0:36:50  | [COUNT] TS:1609 DT:1253
# [PROGRESS] 1640/4185 avg:0.86s/store elapsed:0:23:32 ETA:0:36:32  | [COUNT] TS:1629 DT:1266
# [PROGRESS] 1660/4185 avg:0.86s/store elapsed:0:23:49 ETA:0:36:14  | [COUNT] TS:1649 DT:1280
# [PROGRESS] 1680/4185 avg:0.86s/store elapsed:0:24:06 ETA:0:35:56  | [COUNT] TS:1669 DT:1295
# [PROGRESS] 1700/4185 avg:0.86s/store elapsed:0:24:23 ETA:0:35:38  | [COUNT] TS:1689 DT:1310
# [PROGRESS] 1720/4185 avg:0.86s/store elapsed:0:24:40 ETA:0:35:22  | [COUNT] TS:1709 DT:1328
# [PROGRESS] 1740/4185 avg:0.86s/store elapsed:0:24:55 ETA:0:35:01  | [COUNT] TS:1728 DT:1338
# [PROGRESS] 1760/4185 avg:0.86s/store elapsed:0:25:13 ETA:0:34:45  | [COUNT] TS:1748 DT:1356
# [PROGRESS] 1780/4185 avg:0.86s/store elapsed:0:25:30 ETA:0:34:27  | [COUNT] TS:1768 DT:1370
# [PROGRESS] 1800/4185 avg:0.86s/store elapsed:0:25:45 ETA:0:34:07  | [COUNT] TS:1787 DT:1381
# [CKPT] saved 1800 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 1820/4185 avg:0.86s/store elapsed:0:26:02 ETA:0:33:50  | [COUNT] TS:1807 DT:1395
# [PROGRESS] 1840/4185 avg:0.86s/store elapsed:0:26:19 ETA:0:33:32  | [COUNT] TS:1827 DT:1408
# [PROGRESS] 1860/4185 avg:0.86s/store elapsed:0:26:36 ETA:0:33:15  | [COUNT] TS:1847 DT:1424
# [PROGRESS] 1880/4185 avg:0.86s/store elapsed:0:26:52 ETA:0:32:57  | [COUNT] TS:1867 DT:1439
# [PROGRESS] 1900/4185 avg:0.86s/store elapsed:0:27:09 ETA:0:32:39  | [COUNT] TS:1886 DT:1455
# [PROGRESS] 1920/4185 avg:0.86s/store elapsed:0:27:24 ETA:0:32:20  | [COUNT] TS:1906 DT:1466
# [PROGRESS] 1940/4185 avg:0.86s/store elapsed:0:27:42 ETA:0:32:04  | [COUNT] TS:1926 DT:1482
# [PROGRESS] 1960/4185 avg:0.86s/store elapsed:0:27:59 ETA:0:31:46  | [COUNT] TS:1946 DT:1497
# [PROGRESS] 1980/4185 avg:0.86s/store elapsed:0:28:14 ETA:0:31:27  | [COUNT] TS:1966 DT:1506
# [PROGRESS] 2000/4185 avg:0.86s/store elapsed:0:28:31 ETA:0:31:10  | [COUNT] TS:1986 DT:1519
# [CKPT] saved 2000 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 2020/4185 avg:0.86s/store elapsed:0:28:47 ETA:0:30:51  | [COUNT] TS:2006 DT:1530
# [PROGRESS] 2040/4185 avg:0.86s/store elapsed:0:29:04 ETA:0:30:33  | [COUNT] TS:2026 DT:1543
# [PROGRESS] 2060/4185 avg:0.85s/store elapsed:0:29:19 ETA:0:30:15  | [COUNT] TS:2045 DT:1554
# [PROGRESS] 2080/4185 avg:0.85s/store elapsed:0:29:35 ETA:0:29:56  | [COUNT] TS:2065 DT:1565
# [PROGRESS] 2100/4185 avg:0.85s/store elapsed:0:29:52 ETA:0:29:39  | [COUNT] TS:2085 DT:1579
# [PROGRESS] 2120/4185 avg:0.85s/store elapsed:0:30:08 ETA:0:29:21  | [COUNT] TS:2105 DT:1592
# [PROGRESS] 2140/4185 avg:0.85s/store elapsed:0:30:24 ETA:0:29:03  | [COUNT] TS:2124 DT:1605
# [PROGRESS] 2160/4185 avg:0.85s/store elapsed:0:30:41 ETA:0:28:46  | [COUNT] TS:2144 DT:1616
# [PROGRESS] 2180/4185 avg:0.85s/store elapsed:0:30:57 ETA:0:28:28  | [COUNT] TS:2164 DT:1627
# [PROGRESS] 2200/4185 avg:0.85s/store elapsed:0:31:13 ETA:0:28:10  | [COUNT] TS:2183 DT:1641
# [CKPT] saved 2200 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 2220/4185 avg:0.85s/store elapsed:0:31:30 ETA:0:27:53  | [COUNT] TS:2203 DT:1656
# [PROGRESS] 2240/4185 avg:0.85s/store elapsed:0:31:47 ETA:0:27:36  | [COUNT] TS:2223 DT:1671
# [PROGRESS] 2260/4185 avg:0.85s/store elapsed:0:32:03 ETA:0:27:18  | [COUNT] TS:2242 DT:1685
# [PROGRESS] 2280/4185 avg:0.85s/store elapsed:0:32:19 ETA:0:27:00  | [COUNT] TS:2262 DT:1697
# [PROGRESS] 2300/4185 avg:0.85s/store elapsed:0:32:35 ETA:0:26:43  | [COUNT] TS:2282 DT:1711
# [PROGRESS] 2320/4185 avg:0.85s/store elapsed:0:32:51 ETA:0:26:24  | [COUNT] TS:2302 DT:1722
# [PROGRESS] 2340/4185 avg:0.85s/store elapsed:0:33:06 ETA:0:26:06  | [COUNT] TS:2322 DT:1733
# [PROGRESS] 2360/4185 avg:0.85s/store elapsed:0:33:21 ETA:0:25:47  | [COUNT] TS:2342 DT:1744
# [PROGRESS] 2380/4185 avg:0.85s/store elapsed:0:33:38 ETA:0:25:30  | [COUNT] TS:2362 DT:1758
# [PROGRESS] 2400/4185 avg:0.85s/store elapsed:0:33:53 ETA:0:25:12  | [COUNT] TS:2382 DT:1768
# [CKPT] saved 2400 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 2420/4185 avg:0.85s/store elapsed:0:34:09 ETA:0:24:54  | [COUNT] TS:2401 DT:1779
# [PROGRESS] 2440/4185 avg:0.85s/store elapsed:0:34:25 ETA:0:24:37  | [COUNT] TS:2421 DT:1792
# [PROGRESS] 2460/4185 avg:0.85s/store elapsed:0:34:40 ETA:0:24:18  | [COUNT] TS:2441 DT:1801
# [PROGRESS] 2480/4185 avg:0.85s/store elapsed:0:34:58 ETA:0:24:02  | [COUNT] TS:2461 DT:1818
# [PROGRESS] 2500/4185 avg:0.85s/store elapsed:0:35:13 ETA:0:23:44  | [COUNT] TS:2480 DT:1830
# [PROGRESS] 2520/4185 avg:0.85s/store elapsed:0:35:29 ETA:0:23:27  | [COUNT] TS:2500 DT:1843
# [PROGRESS] 2540/4185 avg:0.84s/store elapsed:0:35:46 ETA:0:23:10  | [COUNT] TS:2520 DT:1856
# [PROGRESS] 2560/4185 avg:0.84s/store elapsed:0:36:01 ETA:0:22:52  | [COUNT] TS:2539 DT:1870
# [PROGRESS] 2580/4185 avg:0.84s/store elapsed:0:36:18 ETA:0:22:35  | [COUNT] TS:2559 DT:1885
# [PROGRESS] 2600/4185 avg:0.84s/store elapsed:0:36:35 ETA:0:22:18  | [COUNT] TS:2579 DT:1899
# [CKPT] saved 2600 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 2620/4185 avg:0.84s/store elapsed:0:36:50 ETA:0:22:00  | [COUNT] TS:2599 DT:1909
# [PROGRESS] 2640/4185 avg:0.84s/store elapsed:0:37:07 ETA:0:21:43  | [COUNT] TS:2619 DT:1923
# [PROGRESS] 2660/4185 avg:0.84s/store elapsed:0:37:23 ETA:0:21:25  | [COUNT] TS:2639 DT:1934
# [PROGRESS] 2680/4185 avg:0.84s/store elapsed:0:37:38 ETA:0:21:08  | [COUNT] TS:2659 DT:1943
# [PROGRESS] 2700/4185 avg:0.84s/store elapsed:0:37:52 ETA:0:20:49  | [COUNT] TS:2677 DT:1952
# [PROGRESS] 2720/4185 avg:0.84s/store elapsed:0:38:08 ETA:0:20:32  | [COUNT] TS:2697 DT:1964
# [PROGRESS] 2740/4185 avg:0.84s/store elapsed:0:38:24 ETA:0:20:15  | [COUNT] TS:2717 DT:1975
# [PROGRESS] 2760/4185 avg:0.84s/store elapsed:0:38:41 ETA:0:19:58  | [COUNT] TS:2736 DT:1990
# [PROGRESS] 2780/4185 avg:0.84s/store elapsed:0:38:57 ETA:0:19:41  | [COUNT] TS:2756 DT:2002
# [PROGRESS] 2800/4185 avg:0.84s/store elapsed:0:39:13 ETA:0:19:24  | [COUNT] TS:2776 DT:2015
# [CKPT] saved 2800 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 2820/4185 avg:0.84s/store elapsed:0:39:29 ETA:0:19:07  | [COUNT] TS:2796 DT:2027
# [PROGRESS] 2840/4185 avg:0.84s/store elapsed:0:39:44 ETA:0:18:49  | [COUNT] TS:2814 DT:2039
# [PROGRESS] 2860/4185 avg:0.84s/store elapsed:0:40:00 ETA:0:18:32  | [COUNT] TS:2833 DT:2051
# [PROGRESS] 2880/4185 avg:0.84s/store elapsed:0:40:17 ETA:0:18:15  | [COUNT] TS:2853 DT:2064
# [PROGRESS] 2900/4185 avg:0.84s/store elapsed:0:40:33 ETA:0:17:58  | [COUNT] TS:2873 DT:2074
# [PROGRESS] 2920/4185 avg:0.84s/store elapsed:0:40:49 ETA:0:17:41  | [COUNT] TS:2892 DT:2086
# [PROGRESS] 2940/4185 avg:0.84s/store elapsed:0:41:06 ETA:0:17:24  | [COUNT] TS:2912 DT:2100
# [PROGRESS] 2960/4185 avg:0.84s/store elapsed:0:41:22 ETA:0:17:07  | [COUNT] TS:2932 DT:2114
# [PROGRESS] 2980/4185 avg:0.84s/store elapsed:0:41:39 ETA:0:16:50  | [COUNT] TS:2952 DT:2127
# [PROGRESS] 3000/4185 avg:0.84s/store elapsed:0:41:55 ETA:0:16:33  | [COUNT] TS:2972 DT:2138
# [CKPT] saved 3000 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 3020/4185 avg:0.84s/store elapsed:0:42:10 ETA:0:16:16  | [COUNT] TS:2992 DT:2147
# [PROGRESS] 3040/4185 avg:0.84s/store elapsed:0:42:27 ETA:0:15:59  | [COUNT] TS:3012 DT:2161
# [PROGRESS] 3060/4185 avg:0.84s/store elapsed:0:42:43 ETA:0:15:42  | [COUNT] TS:3032 DT:2173
# [PROGRESS] 3080/4185 avg:0.84s/store elapsed:0:42:58 ETA:0:15:25  | [COUNT] TS:3052 DT:2182
# [PROGRESS] 3100/4185 avg:0.84s/store elapsed:0:43:14 ETA:0:15:07  | [COUNT] TS:3071 DT:2192
# [PROGRESS] 3120/4185 avg:0.84s/store elapsed:0:43:31 ETA:0:14:51  | [COUNT] TS:3091 DT:2205
# [PROGRESS] 3140/4185 avg:0.84s/store elapsed:0:43:46 ETA:0:14:33  | [COUNT] TS:3110 DT:2215
# [PROGRESS] 3160/4185 avg:0.84s/store elapsed:0:44:02 ETA:0:14:17  | [COUNT] TS:3129 DT:2229
# [PROGRESS] 3180/4185 avg:0.84s/store elapsed:0:44:18 ETA:0:14:00  | [COUNT] TS:3148 DT:2245
# [PROGRESS] 3200/4185 avg:0.84s/store elapsed:0:44:35 ETA:0:13:43  | [COUNT] TS:3168 DT:2260
# [CKPT] saved 3200 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 3220/4185 avg:0.84s/store elapsed:0:44:52 ETA:0:13:26  | [COUNT] TS:3188 DT:2273
# [PROGRESS] 3240/4185 avg:0.84s/store elapsed:0:45:09 ETA:0:13:10  | [COUNT] TS:3208 DT:2290
# [PROGRESS] 3260/4185 avg:0.84s/store elapsed:0:45:24 ETA:0:12:53  | [COUNT] TS:3228 DT:2300
# [PROGRESS] 3280/4185 avg:0.84s/store elapsed:0:45:39 ETA:0:12:35  | [COUNT] TS:3245 DT:2312
# [PROGRESS] 3300/4185 avg:0.84s/store elapsed:0:45:57 ETA:0:12:19  | [COUNT] TS:3265 DT:2328
# [PROGRESS] 3320/4185 avg:0.84s/store elapsed:0:46:13 ETA:0:12:02  | [COUNT] TS:3285 DT:2342
# [PROGRESS] 3340/4185 avg:0.84s/store elapsed:0:46:31 ETA:0:11:46  | [COUNT] TS:3305 DT:2357
# [PROGRESS] 3360/4185 avg:0.84s/store elapsed:0:46:48 ETA:0:11:29  | [COUNT] TS:3325 DT:2371
# [PROGRESS] 3380/4185 avg:0.83s/store elapsed:0:47:02 ETA:0:11:12  | [COUNT] TS:3343 DT:2382
# [PROGRESS] 3400/4185 avg:0.83s/store elapsed:0:47:17 ETA:0:10:55  | [COUNT] TS:3363 DT:2392
# [CKPT] saved 3400 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 3420/4185 avg:0.83s/store elapsed:0:47:33 ETA:0:10:38  | [COUNT] TS:3383 DT:2403
# [PROGRESS] 3440/4185 avg:0.83s/store elapsed:0:47:48 ETA:0:10:21  | [COUNT] TS:3403 DT:2413
# [PROGRESS] 3460/4185 avg:0.83s/store elapsed:0:48:04 ETA:0:10:04  | [COUNT] TS:3423 DT:2422
# [PROGRESS] 3480/4185 avg:0.83s/store elapsed:0:48:20 ETA:0:09:47  | [COUNT] TS:3442 DT:2436
# [PROGRESS] 3500/4185 avg:0.83s/store elapsed:0:48:37 ETA:0:09:30  | [COUNT] TS:3462 DT:2450
# [PROGRESS] 3520/4185 avg:0.83s/store elapsed:0:48:53 ETA:0:09:14  | [COUNT] TS:3482 DT:2463
# [PROGRESS] 3540/4185 avg:0.83s/store elapsed:0:49:10 ETA:0:08:57  | [COUNT] TS:3502 DT:2476
# [PROGRESS] 3560/4185 avg:0.83s/store elapsed:0:49:27 ETA:0:08:40  | [COUNT] TS:3522 DT:2489
# [PROGRESS] 3580/4185 avg:0.83s/store elapsed:0:49:43 ETA:0:08:24  | [COUNT] TS:3542 DT:2502
# [PROGRESS] 3600/4185 avg:0.83s/store elapsed:0:49:59 ETA:0:08:07  | [COUNT] TS:3561 DT:2514
# [CKPT] saved 3600 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 3620/4185 avg:0.83s/store elapsed:0:50:13 ETA:0:07:50  | [COUNT] TS:3578 DT:2524
# [PROGRESS] 3640/4185 avg:0.83s/store elapsed:0:50:28 ETA:0:07:33  | [COUNT] TS:3597 DT:2534
# [PROGRESS] 3660/4185 avg:0.83s/store elapsed:0:50:45 ETA:0:07:16  | [COUNT] TS:3617 DT:2546
# [PROGRESS] 3680/4185 avg:0.83s/store elapsed:0:51:01 ETA:0:07:00  | [COUNT] TS:3636 DT:2556
# [PROGRESS] 3700/4185 avg:0.83s/store elapsed:0:51:16 ETA:0:06:43  | [COUNT] TS:3656 DT:2566
# [PROGRESS] 3720/4185 avg:0.83s/store elapsed:0:51:33 ETA:0:06:26  | [COUNT] TS:3676 DT:2579
# [PROGRESS] 3740/4185 avg:0.83s/store elapsed:0:51:49 ETA:0:06:10  | [COUNT] TS:3696 DT:2590
# [PROGRESS] 3760/4185 avg:0.83s/store elapsed:0:52:06 ETA:0:05:53  | [COUNT] TS:3716 DT:2600
# [PROGRESS] 3780/4185 avg:0.83s/store elapsed:0:52:23 ETA:0:05:36  | [COUNT] TS:3736 DT:2615
# [PROGRESS] 3800/4185 avg:0.83s/store elapsed:0:52:40 ETA:0:05:20  | [COUNT] TS:3756 DT:2629
# [CKPT] saved 3800 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 3820/4185 avg:0.83s/store elapsed:0:52:54 ETA:0:05:03  | [COUNT] TS:3772 DT:2641
# [PROGRESS] 3840/4185 avg:0.83s/store elapsed:0:53:09 ETA:0:04:46  | [COUNT] TS:3791 DT:2653
# [PROGRESS] 3860/4185 avg:0.83s/store elapsed:0:53:23 ETA:0:04:29  | [COUNT] TS:3809 DT:2661
# [PROGRESS] 3880/4185 avg:0.83s/store elapsed:0:53:37 ETA:0:04:12  | [COUNT] TS:3828 DT:2670
# [PROGRESS] 3900/4185 avg:0.83s/store elapsed:0:53:53 ETA:0:03:56  | [COUNT] TS:3848 DT:2681
# [PROGRESS] 3920/4185 avg:0.83s/store elapsed:0:54:09 ETA:0:03:39  | [COUNT] TS:3868 DT:2690
# [PROGRESS] 3940/4185 avg:0.83s/store elapsed:0:54:23 ETA:0:03:22  | [COUNT] TS:3887 DT:2700
# [PROGRESS] 3960/4185 avg:0.83s/store elapsed:0:54:39 ETA:0:03:06  | [COUNT] TS:3907 DT:2710
# [PROGRESS] 3980/4185 avg:0.83s/store elapsed:0:54:54 ETA:0:02:49  | [COUNT] TS:3926 DT:2722
# [PROGRESS] 4000/4185 avg:0.83s/store elapsed:0:55:09 ETA:0:02:33  | [COUNT] TS:3945 DT:2731
# [CKPT] saved 4000 rows -> store_unique_with_google_rating.csv
# [PROGRESS] 4020/4185 avg:0.83s/store elapsed:0:55:26 ETA:0:02:16  | [COUNT] TS:3965 DT:2746
# [PROGRESS] 4040/4185 avg:0.83s/store elapsed:0:55:43 ETA:0:01:59  | [COUNT] TS:3985 DT:2756
# [PROGRESS] 4060/4185 avg:0.83s/store elapsed:0:55:57 ETA:0:01:43  | [COUNT] TS:4004 DT:2765
# [PROGRESS] 4080/4185 avg:0.83s/store elapsed:0:56:13 ETA:0:01:26  | [COUNT] TS:4023 DT:2777
# [PROGRESS] 4100/4185 avg:0.83s/store elapsed:0:56:28 ETA:0:01:10  | [COUNT] TS:4043 DT:2789
# [PROGRESS] 4120/4185 avg:0.83s/store elapsed:0:56:43 ETA:0:00:53  | [COUNT] TS:4061 DT:2799
# [PROGRESS] 4140/4185 avg:0.83s/store elapsed:0:56:59 ETA:0:00:37  | [COUNT] TS:4080 DT:2812
# [PROGRESS] 4160/4185 avg:0.83s/store elapsed:0:57:14 ETA:0:00:20  | [COUNT] TS:4097 DT:2822
# [PROGRESS] 4180/4185 avg:0.83s/store elapsed:0:57:31 ETA:0:00:04  | [COUNT] TS:4117 DT:2835
# [DONE] saved -> store_unique_with_google_rating.csv (rows: 4185)
# [COUNT] TS:4122 / DT:2838
# [SUMMARY] 4185/4185 avg:0.83s/store elapsed:0:57:35 ETA:0:00:00

# %%
pip install requests pandas
# Out:
# Requirement already satisfied: requests in c:\users\pimet\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\pimet\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pimet\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pimet\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pimet\anaconda3\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pimet\anaconda3\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\pimet\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\pimet\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pimet\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\pimet\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\pimet\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# df 라는 DataFrame이 있다고 가정
import pandas as pd

path = "store_unique_with_google_rating.csv"  # 경로만 바꿔주세요
df = pd.read_csv(path)

out_path = "C:\\Users\\pimet\\Downloads\\store_unique_with_google_rating.csv"  # 원하는 경로

# 엑셀에서 한글 안 깨지게 저장
df.to_csv(out_path, index=False, encoding="utf-8-sig")

print("saved ->", out_path)
# Out:
# saved -> C:\Users\pimet\Downloads\store_unique_with_google_rating.csv
